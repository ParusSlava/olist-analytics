# %% [markdown]
# <a href="https://colab.research.google.com/github/ParusSlava/olist-analytics/blob/main/notebook/olist_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 3. Python: A Simple Forecast and Recommendations
# # Teil 3. Python: Einfache Prognose und Empfehlungen
# # Частина 3. Python: простий прогноз і рекомендації
